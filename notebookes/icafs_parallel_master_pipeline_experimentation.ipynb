# %%
# Standard Library
import random
import time

# Data Processing
import numpy as np
import pandas as pd
from numpy import inf

# Visualization
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import seaborn as sns
from mpl_toolkits import mplot3d

# Machine Learning
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import f1_score, accuracy_score
from sklearn.svm import SVC

# Dimensionality Reduction & Utilities
import umap
from joblib import Parallel, delayed

# Feature Selection
from testflows.combinatorics import Covering
from Py_FS.wrapper.population_based.BBA import BBA as BBA
from Py_FS.wrapper.population_based.PSO import PSO as PSO
from Py_FS.wrapper.population_based.CS import CS as CS

# %% [markdown]
# # Datasets

# %%
df_cis = pd.read_csv('../data/cis_data.csv')
df_cacao = pd.read_csv(r'../data/data_temp/cacao.csv')
df_algarrobo = pd.read_csv(r'../data/data_temp/algarrobo.csv')
df_fruits_pures = pd.read_csv(r'../data/data_temp/MIR_Fruit_purees.csv')
df_fresh_meat = pd.read_csv(r'../data/data_temp/Fresh_meats.csv')
df_olive = pd.read_csv(r'../data/data_temp/Olive_Oils_Quadrum.csv')


df_x_cacao = df_cacao.iloc[:, 1:]
y_cacao = df_cacao.iloc[:, 0:1]

unique_names_algarrobo = df_algarrobo['Labels'].unique()
algarrobo_x = df_algarrobo.loc[:, 'R':'REDVI']
y_algarrobo = df_algarrobo['Labels'].replace(to_replace=['N', 'P'], value=[0, 1]).to_frame()

cis_x = df_cis[['X', 'Y', 'X10', 'Y10', 'X20', 'Y20', 'X30', 'Y30', 'X40', 'Y40']]
y_cis = df_cis[['Result']]

unique_names_berry = df_fruits_pures["label"].unique()
fruits_pures_x = df_fruits_pures.iloc[:,1:]
y_fruit_puree = df_fruits_pures.iloc[:,0:1].replace(to_replace=unique_names_berry, value =range(0,len(unique_names_berry)))


unique_names_meat = df_fresh_meat["meat"].unique()
meat_x = df_fresh_meat.iloc[:,4:]
y_meat = df_fresh_meat.iloc[:,0:1].replace(to_replace=unique_names_meat,value=range(0,len(unique_names_meat)))

unique_names_olive = df_olive["Provenance"].unique()
olive_x = df_olive.iloc[:,3:]
y_olive = df_olive.iloc[:,2:3].replace(to_replace=unique_names_olive,value=range(0,len(unique_names_olive)))

covering_array  = np.loadtxt(r'../data/coveringArray.csv', delimiter=",", dtype=int)

# %% [markdown]
# # ICAFS/CAFS Base Function

# %%
def ICAFS(dataset_X, dataset_Y, strenght,max_iteartion,model, print_logs=False):
  
  max_it = 1 

  v_variable = [0, 1]
  best_f1_score = float('-inf')
  max_iteartion_aux =  max_iteartion
  best_data_set = dataset_X.columns.values.copy()

  global_best_score = float('-inf')
  global_best_features = dataset_X.columns.values.copy()

  while max_iteartion_aux > 0:
      
      partial_score = 0
      dict_parameters = {}
      lst_of_featutres_to_check = []

      for colum_key in best_data_set:
          dict_parameters[colum_key] = v_variable
      generate_covering_array = Covering(dict_parameters, strength=strenght)
      for i,test in  enumerate(generate_covering_array.array):
          list_attributes_to_consider = []

          check_for_all_cero = True
          for (test_key, test_value) in test.items():
              if test_value == 1:
                  check_for_all_cero = False
                  list_attributes_to_consider.append(test_key)

          if check_for_all_cero:
              continue  
          lst_of_featutres_to_check.append((list_attributes_to_consider,i))
      
      clf_new = train_model(model)
      results = Parallel(n_jobs=-1)(delayed(run_cv)(clf_new, dataset_X, subset_features, dataset_Y.values.ravel(), i) for subset_features,i in lst_of_featutres_to_check)   
      sorted_results = sorted(results, key=lambda x: x[2])
      
      for score, std, i, subset_features in sorted_results:
        if score >= partial_score:
              partial_score = score
              best_std = std
              best_data_set = subset_features.copy()
      
      if partial_score >= global_best_score:
            global_best_score = partial_score
            global_best_features = best_data_set.copy()

      clf_new = None
      best_f1_score = partial_score
      
      if print_logs:
        print(f"best f1 score= {best_f1_score}, iteration:{max_it}, numbers features selected ={ len(best_data_set)},best features selected={', '.join(best_data_set)}" )

      max_it = max_it +1
      max_iteartion_aux = max_iteartion_aux-1
  return global_best_features

def train_model(model_name):  

    m = eval(model_name)
    return m

def run_cv(model, X, subset_features, y, index):

    scores = cross_val_score(model, X[subset_features].values, y, cv=5, scoring='f1_macro',n_jobs=1)
    return (scores.mean(), scores.std(), index, subset_features)

# %%
def CAFS(ca,dataset_x,dataset_y, max_iter ,clasifier,print_logs=False):

  max_iteartion = 0
  num_rows = ca.shape[0]
  next_features_data_set_selected = dataset_x.columns.values.copy()

  best_score_global = float('-inf')
  best_features_global = dataset_x.columns.values.copy()

  if len(dataset_x.columns) < ca.shape[1] :
    num_colums = len(dataset_x.columns)
  else:
    num_colums = ca.shape[1]

  while max_iteartion < max_iter:
          
     max_score = 0.0
     mx_data_set = None

     lst_of_subsets_to_run = []
     lst_headers = next_features_data_set_selected.copy()
    
     for i in range(0,num_rows):
        lst_headers_to_select = []
        for j in range(0,num_colums ):
          if ca[i][j] == 1 :
              lst_headers_to_select.append(lst_headers[j])
        if len(lst_headers_to_select) == 0:
            continue
        lst_of_subsets_to_run.append((lst_headers_to_select,i))
     
     results = Parallel(n_jobs=-1)(delayed(run_cv)(clasifier, dataset_x, subset_features, dataset_y.values.ravel(), i) for subset_features,i in lst_of_subsets_to_run)
     sorted_results = sorted(results, key=lambda x: x[2])
     for score, std, i, subset_features in sorted_results:
        if score >= max_score:
              max_score = score
              mx_data_set = subset_features.copy()
              
     if max_score >= best_score_global:
          best_score_global = max_score
          best_features_global = mx_data_set.copy()
          
     next_features_data_set_selected = mx_data_set.copy()
     if print_logs:
         print(f"best f1 score= {max_score}, iteration:{max_iteartion}, numbers features selected ={len(mx_data_set)},best features selected={', '.join(mx_data_set)}" )

     num_colums  = len(next_features_data_set_selected)
     max_iteartion = max_iteartion  +1

  return best_features_global, best_score_global

def run_cv(model, X, subset_features, y, index):
    scores = cross_val_score(model, X[subset_features].values, y, cv=5, scoring='f1_macro',n_jobs=1)
    return (scores.mean(), scores.std(), index, subset_features)

# %% [markdown]
# ## Master Pipeline

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import f1_score
from scipy.stats import wilcoxon
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')

def evaluate_dataset_nested(X, y, dataset_name, outer_splits=5):
    
    print(f"\n{'='*50}")
    print(f"Starting NESTED CV for Dataset: {dataset_name}")
    print(f"{'='*50}")

    # THE OUTER LOOP (The Judge)
    # This splits the data into 'outer_splits' (e.g., 5) folds.
    
    complete_list_of_features = X.columns.values.copy()
    outer_cv = StratifiedKFold(n_splits=outer_splits, shuffle=True, random_state=42)
    
    # Store the scores for every fold
    fold_scores = {'ICAFS': [], 'CAFS': [], 'BBA': [], 'PSO': [], 'CS': []}
    selected_wavelengths = {'ICAFS': [], 'CAFS': [], 'BBA': [], 'PSO': [], 'CS': []}

    for fold_idx, (train_idx, test_idx) in enumerate(outer_cv.split(X, y)):
        print(f"\n--- Processing Outer Fold {fold_idx + 1} / {outer_splits} ---")
        
        # 1. Create the Training Data and The Vault for this specific fold
        X_train, X_test = X.iloc[train_idx, :], X.iloc[test_idx, :]
        y_train, y_test = y.iloc[train_idx, :], y.iloc[test_idx, :]
        
        # ---------------------------------------------------------
        # PHASE 1: FEATURE SELECTION (The Scout)
        # ---------------------------------------------------------
        print("  > Running Feature Selection on Training Data...")
        
        scaler = MinMaxScaler()
        scaler.set_output(transform="pandas")

        scaler.fit(X_train)
        X_train_scaled = scaler.transform(X_train)
        X_test_scaled = scaler.transform(X_test)
        
        bba = BBA(num_agents=60, max_iter=20, train_data=X_train_scaled, train_label=y_train,save_conv_graph=False,default_mode=True,verbose=False).run()
        pso = PSO(num_agents=60, max_iter=20, train_data=X_train_scaled, train_label=y_train,save_conv_graph=False,default_mode=True,verbose=False).run()
        cs = CS(num_agents=60, max_iter=20, train_data=X_train_scaled, train_label=y_train,save_conv_graph=False,default_mode=True,verbose=False).run()

        icafs_features = ICAFS(X_train_scaled,y_train,2,10,'KNeighborsClassifier()', print_logs=False)
        cafs_features = CAFS(covering_array,X_train_scaled,y_train,10,KNeighborsClassifier(),print_logs=False)[0]
        bba_features = [complete_list_of_features[i] for i in range(len(bba.Leader_agent)) if bba.Leader_agent[i] == 1]
        pso_features = [complete_list_of_features[i] for i in range(len(pso.Leader_agent)) if pso.Leader_agent[i] == 1]
        cs_features = [complete_list_of_features[i] for i in range(len(cs.Leader_agent)) if cs.Leader_agent[i] == 1]

        feature_dict = {
            'ICAFS': icafs_features,
            'CAFS': cafs_features,
            'BBA': bba_features,
            'PSO': pso_features,
            'CS': cs_features
        }
        
        # ---------------------------------------------------------
        # PHASE 2 & 3: INNER CV TUNING AND VAULT EVALUATION
        # ---------------------------------------------------------
        print("  > Tuning SVMs and Evaluating on Vault Data...")
        
        svm_param_grid = {
            'C': [0.1, 1, 10, 100],
            'gamma': ['scale', 'auto', 0.01, 0.1],
            'kernel': ['rbf', 'linear']
        }
        
        for algo_name, selected_features in feature_dict.items():
            if len(selected_features) == 0:
                fold_scores[algo_name].append(0.0)
                continue
                
            X_train_masked = X_train_scaled[selected_features]
            X_test_masked = X_test_scaled[selected_features]
            
            # Phase 2: INNER CV (GridSearchCV automatically splits X_train again internally)
            grid_search = GridSearchCV(SVC(random_state=42), svm_param_grid, cv=5, scoring='f1_macro', n_jobs=-1)
            grid_search.fit(X_train_masked, y_train)
            
            best_svm = grid_search.best_estimator_
            
            # Phase 3: Evaluate on the unseen Test Data (The Vault) for this fold
            y_pred = best_svm.predict(X_test_masked)
            fold_f1 = f1_score(y_test, y_pred, average='macro')
            
            fold_scores[algo_name].append(fold_f1)
            selected_wavelengths[algo_name].append(len(selected_features))

            print(f"    - {algo_name} Fold {fold_idx + 1} F1: {fold_f1:.4f}")
            print(f"  > {algo_name} Final F1-Score: {fold_f1:.4f} (Features: {len(selected_features)})")


    # Calculate the average score across all folds
    final_avg_scores = {algo: np.mean(scores) for algo, scores in fold_scores.items()}
    final_avg_wavelengths = {algo: np.mean(wavelengths_number) for algo, wavelengths_number in selected_wavelengths.items()}
    final_std_features = {algo: np.std(wavelengths_number) for algo, wavelengths_number in selected_wavelengths.items()}
    final_avg_std = {algo: np.std(scores) for algo, scores in fold_scores.items()}

    print(f"\n>>> FINAL AVERAGED RESULTS FOR {dataset_name} <<<")
    for algo in final_avg_scores.keys():
        print(f"  {algo}: F1 = {final_avg_scores[algo]:.4f} (± {final_avg_std[algo]:.4f}) | Features = {final_avg_wavelengths[algo]:.1f} (± {final_std_features[algo]:.1f})")
    
    return final_avg_scores, final_avg_wavelengths,final_std_features, final_avg_std

# %% [markdown]
# # Master Pipeline Execution

# %%
datasets = [[df_x_cacao, y_cacao, "Cacao "],[meat_x, y_meat, "Meat"],[olive_x, y_olive, "Olive"],[fruits_pures_x, y_fruit_puree, "Fruit Puree Dataset"],[cis_x,y_cis, "CIS"],[algarrobo_x, y_algarrobo, "Algarrobo"]]
#datasets = [[olive_x, y_olive, "Olive"]]

results = {'Dataset': [], 'ICAFS': [], 'CAFS': [], 'BBA': [], 'PSO': [], 'CS': []}
results_features = {'Dataset': [], 'ICAFS Features': [], 'CAFS Features': [], 'BBA Features': [], 'PSO Features': [], 'CS Features': []}
results_std_score = {'Dataset': [], 'ICAFS': [], 'CAFS': [], 'BBA': [], 'PSO': [], 'CS': []}


for X, y, name in datasets:
    scores,num_of_wavelengths,std_final,final_avg_std = evaluate_dataset_nested(X, y, name)
    
    results['Dataset'].append(name)
    results['ICAFS'].append(scores['ICAFS'])
    results['CAFS'].append(scores['CAFS'])
    results['BBA'].append(scores['BBA'])
    results['PSO'].append(scores['PSO'])
    results['CS'].append(scores['CS'])

    results_std_score['Dataset'].append(name)
    results_std_score['ICAFS'].append(final_avg_std['ICAFS'])
    results_std_score['CAFS'].append(final_avg_std['CAFS'])
    results_std_score['BBA'].append(final_avg_std['BBA'])
    results_std_score['PSO'].append(final_avg_std['PSO'])
    results_std_score['CS'].append(final_avg_std['CS'])

    results_features['Dataset'].append(name)
    results_features['ICAFS Features'].append(f"{num_of_wavelengths['ICAFS']:.1f} (± {std_final['ICAFS']:.1f})")
    results_features['CAFS Features'].append(f"{num_of_wavelengths['CAFS']:.1f} (± {std_final['CAFS']:.1f})")
    results_features['BBA Features'].append(f"{num_of_wavelengths['BBA']:.1f} (± {std_final['BBA']:.1f})")
    results_features['PSO Features'].append(f"{num_of_wavelengths['PSO']:.1f} (± {std_final['PSO']:.1f})")
    results_features['CS Features'].append(f"{num_of_wavelengths['CS']:.1f} (± {std_final['CS']:.1f})")

# Create a DataFrame for easy viewing and exporting to CSV
df_results = pd.DataFrame(results)
df_results_features = pd.DataFrame(results_features)
df_results_std_score = pd.DataFrame(results_std_score)

print("\n==================================================")
print("FINAL RESULTS TABLE (Phase 3 F1-Scores)")
print("==================================================")
print(df_results.to_string(index=False))

print("\n==================================================")
print("FINAL NUMBER OF FEATURES RESULTS TABLE")
print("==================================================")
print(df_results_features.to_string(index=False))

print("\n==================================================")
print("FINAL STANDARD DEVIATION RESULTS TABLE")
print("==================================================")
print(df_results_std_score.to_string(index=False))

# Export to CSV so you don't lose the data!
df_results.to_csv('final_f1_scores_revision.csv', index=False)
df_results_features.to_csv('final_features_revision.csv', index=False)
df_results_std_score.to_csv('final_std_scores_revision.csv', index=False)

# ---------------------------------------------------------
# PHASE 4: STATISTICAL VALIDATION (Reviewer 2 Fix)
# ---------------------------------------------------------
print("\n==================================================")
print("STATISTICAL SIGNIFICANCE (Wilcoxon Signed-Rank Test)")
print("==================================================")

baselines = ['BBA', 'PSO', 'CS']
for baseline in baselines:
    # Compare ICAFS scores against the baseline scores across the 6 datasets
    stat, p_value = wilcoxon(df_results['ICAFS'], df_results[baseline])
    
    print(f"ICAFS vs {baseline}:")
    print(f"  - p-value: {p_value:.4f}")
    if p_value < 0.05:
        print("  - Result: ICAFS is STATISTICALLY SIGNIFICANTLY better.\n")
    else:
        print("  - Result: Difference is not statistically significant (p >= 0.05).\n")
for baseline in baselines:
    # Compare CAFS scores against the baseline scores across the 6 datasets
    stat, p_value = wilcoxon(df_results['CAFS'], df_results[baseline])
    
    print(f"CAFS vs {baseline}:")
    print(f"  - p-value: {p_value:.4f}")
    if p_value < 0.05:
        print("  - Result: CAFS is STATISTICALLY SIGNIFICANTLY better.\n")
    else:
        print("  - Result: Difference is not statistically significant (p >= 0.05).\n")
# Out:
# ==================================================
# Starting NESTED CV for Dataset: Cacao
# ==================================================
#
# --- Processing Outer Fold 1 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 1 F1: 1.0000
#   > ICAFS Final F1-Score: 1.0000 (Features: 7)
#     - CAFS Fold 1 F1: 1.0000
#   > CAFS Final F1-Score: 1.0000 (Features: 4)
#     - BBA Fold 1 F1: 1.0000
#   > BBA Final F1-Score: 1.0000 (Features: 413)
#     - PSO Fold 1 F1: 1.0000
#   > PSO Final F1-Score: 1.0000 (Features: 604)
#     - CS Fold 1 F1: 1.0000
#   > CS Final F1-Score: 1.0000 (Features: 421)
#
# --- Processing Outer Fold 2 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 2 F1: 1.0000
#   > ICAFS Final F1-Score: 1.0000 (Features: 74)
#     - CAFS Fold 2 F1: 1.0000
#   > CAFS Final F1-Score: 1.0000 (Features: 4)
#     - BBA Fold 2 F1: 1.0000
#   > BBA Final F1-Score: 1.0000 (Features: 476)
#     - PSO Fold 2 F1: 1.0000
#   > PSO Final F1-Score: 1.0000 (Features: 601)
#     - CS Fold 2 F1: 1.0000
#   > CS Final F1-Score: 1.0000 (Features: 699)
#
# --- Processing Outer Fold 3 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 3 F1: 1.0000
#   > ICAFS Final F1-Score: 1.0000 (Features: 7)
#     - CAFS Fold 3 F1: 1.0000
#   > CAFS Final F1-Score: 1.0000 (Features: 4)
#     - BBA Fold 3 F1: 1.0000
#   > BBA Final F1-Score: 1.0000 (Features: 427)
#     - PSO Fold 3 F1: 1.0000
#   > PSO Final F1-Score: 1.0000 (Features: 584)
#     - CS Fold 3 F1: 1.0000
#   > CS Final F1-Score: 1.0000 (Features: 431)
#
# --- Processing Outer Fold 4 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 4 F1: 0.9852
#   > ICAFS Final F1-Score: 0.9852 (Features: 18)
#     - CAFS Fold 4 F1: 0.9861
#   > CAFS Final F1-Score: 0.9861 (Features: 7)
#     - BBA Fold 4 F1: 1.0000
#   > BBA Final F1-Score: 1.0000 (Features: 411)
#     - PSO Fold 4 F1: 1.0000
#   > PSO Final F1-Score: 1.0000 (Features: 604)
#     - CS Fold 4 F1: 1.0000
#   > CS Final F1-Score: 1.0000 (Features: 421)
#
# --- Processing Outer Fold 5 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 5 F1: 0.9955
#   > ICAFS Final F1-Score: 0.9955 (Features: 10)
#     - CAFS Fold 5 F1: 0.9638
#   > CAFS Final F1-Score: 0.9638 (Features: 6)
#     - BBA Fold 5 F1: 0.9955
#   > BBA Final F1-Score: 0.9955 (Features: 452)
#     - PSO Fold 5 F1: 0.9955
#   > PSO Final F1-Score: 0.9955 (Features: 587)
#     - CS Fold 5 F1: 0.9955
#   > CS Final F1-Score: 0.9955 (Features: 463)
#
# >>> FINAL AVERAGED RESULTS FOR Cacao  <<<
#   ICAFS: F1 = 0.9961 (± 0.0057) | Features = 23.2 (± 25.7)
#   CAFS: F1 = 0.9900 (± 0.0141) | Features = 5.0 (± 1.3)
#   BBA: F1 = 0.9991 (± 0.0018) | Features = 435.8 (± 24.9)
#   PSO: F1 = 0.9991 (± 0.0018) | Features = 596.0 (± 8.7)
#   CS: F1 = 0.9991 (± 0.0018) | Features = 487.0 (± 107.1)
#
# ==================================================
# Starting NESTED CV for Dataset: Meat
# ==================================================
#
# --- Processing Outer Fold 1 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 1 F1: 1.0000
#   > ICAFS Final F1-Score: 1.0000 (Features: 30)
#     - CAFS Fold 1 F1: 1.0000
#   > CAFS Final F1-Score: 1.0000 (Features: 8)
#     - BBA Fold 1 F1: 1.0000
#   > BBA Final F1-Score: 1.0000 (Features: 133)
#     - PSO Fold 1 F1: 1.0000
#   > PSO Final F1-Score: 1.0000 (Features: 208)
#     - CS Fold 1 F1: 1.0000
#   > CS Final F1-Score: 1.0000 (Features: 144)
#
# --- Processing Outer Fold 2 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 2 F1: 1.0000
#   > ICAFS Final F1-Score: 1.0000 (Features: 6)
#     - CAFS Fold 2 F1: 1.0000
#   > CAFS Final F1-Score: 1.0000 (Features: 5)
#     - BBA Fold 2 F1: 0.9582
#   > BBA Final F1-Score: 0.9582 (Features: 128)
#     - PSO Fold 2 F1: 0.9582
#   > PSO Final F1-Score: 0.9582 (Features: 205)
#     - CS Fold 2 F1: 0.9582
#   > CS Final F1-Score: 0.9582 (Features: 33)
#
# --- Processing Outer Fold 3 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 3 F1: 0.9153
#   > ICAFS Final F1-Score: 0.9153 (Features: 7)
#     - CAFS Fold 3 F1: 0.9167
#   > CAFS Final F1-Score: 0.9167 (Features: 4)
#     - BBA Fold 3 F1: 0.9153
#   > BBA Final F1-Score: 0.9153 (Features: 170)
#     - PSO Fold 3 F1: 0.9582
#   > PSO Final F1-Score: 0.9582 (Features: 194)
#     - CS Fold 3 F1: 0.9582
#   > CS Final F1-Score: 0.9582 (Features: 179)
#
# --- Processing Outer Fold 4 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 4 F1: 0.9582
#   > ICAFS Final F1-Score: 0.9582 (Features: 7)
#     - CAFS Fold 4 F1: 1.0000
#   > CAFS Final F1-Score: 1.0000 (Features: 26)
#     - BBA Fold 4 F1: 1.0000
#   > BBA Final F1-Score: 1.0000 (Features: 139)
#     - PSO Fold 4 F1: 1.0000
#   > PSO Final F1-Score: 1.0000 (Features: 192)
#     - CS Fold 4 F1: 1.0000
#   > CS Final F1-Score: 1.0000 (Features: 144)
#
# --- Processing Outer Fold 5 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 5 F1: 0.9185
#   > ICAFS Final F1-Score: 0.9185 (Features: 26)
#     - CAFS Fold 5 F1: 0.9582
#   > CAFS Final F1-Score: 0.9582 (Features: 7)
#     - BBA Fold 5 F1: 0.9582
#   > BBA Final F1-Score: 0.9582 (Features: 137)
#     - PSO Fold 5 F1: 0.9582
#   > PSO Final F1-Score: 0.9582 (Features: 190)
#     - CS Fold 5 F1: 0.9185
#   > CS Final F1-Score: 0.9185 (Features: 33)
#
# >>> FINAL AVERAGED RESULTS FOR Meat <<<
#   ICAFS: F1 = 0.9584 (± 0.0372) | Features = 15.2 (± 10.5)
#   CAFS: F1 = 0.9750 (± 0.0333) | Features = 10.0 (± 8.1)
#   BBA: F1 = 0.9663 (± 0.0316) | Features = 141.4 (± 14.8)
#   PSO: F1 = 0.9749 (± 0.0205) | Features = 197.8 (± 7.3)
#   CS: F1 = 0.9670 (± 0.0306) | Features = 106.6 (± 61.4)
#
# ==================================================
# Starting NESTED CV for Dataset: Olive
# ==================================================
#
# --- Processing Outer Fold 1 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 1 F1: 0.8438
#   > ICAFS Final F1-Score: 0.8438 (Features: 34)
#     - CAFS Fold 1 F1: 0.8438
#   > CAFS Final F1-Score: 0.8438 (Features: 5)
#     - BBA Fold 1 F1: 0.8438
#   > BBA Final F1-Score: 0.8438 (Features: 170)
#     - PSO Fold 1 F1: 0.8438
#   > PSO Final F1-Score: 0.8438 (Features: 246)
#     - CS Fold 1 F1: 0.8438
#   > CS Final F1-Score: 0.8438 (Features: 183)
#
# --- Processing Outer Fold 2 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 2 F1: 1.0000
#   > ICAFS Final F1-Score: 1.0000 (Features: 58)
#     - CAFS Fold 2 F1: 0.8987
#   > CAFS Final F1-Score: 0.8987 (Features: 6)
#     - BBA Fold 2 F1: 0.9702
#   > BBA Final F1-Score: 0.9702 (Features: 180)
#     - PSO Fold 2 F1: 1.0000
#   > PSO Final F1-Score: 1.0000 (Features: 242)
#     - CS Fold 2 F1: 0.9199
#   > CS Final F1-Score: 0.9199 (Features: 4)
#
# --- Processing Outer Fold 3 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 3 F1: 0.8605
#   > ICAFS Final F1-Score: 0.8605 (Features: 63)
#     - CAFS Fold 3 F1: 0.8560
#   > CAFS Final F1-Score: 0.8560 (Features: 7)
#     - BBA Fold 3 F1: 0.8486
#   > BBA Final F1-Score: 0.8486 (Features: 196)
#     - PSO Fold 3 F1: 0.8486
#   > PSO Final F1-Score: 0.8486 (Features: 254)
#     - CS Fold 3 F1: 0.6952
#   > CS Final F1-Score: 0.6952 (Features: 4)
#
# --- Processing Outer Fold 4 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 4 F1: 0.9511
#   > ICAFS Final F1-Score: 0.9511 (Features: 59)
#     - CAFS Fold 4 F1: 0.9083
#   > CAFS Final F1-Score: 0.9083 (Features: 13)
#     - BBA Fold 4 F1: 1.0000
#   > BBA Final F1-Score: 1.0000 (Features: 209)
#     - PSO Fold 4 F1: 1.0000
#   > PSO Final F1-Score: 1.0000 (Features: 232)
#     - CS Fold 4 F1: 0.8615
#   > CS Final F1-Score: 0.8615 (Features: 4)
#
# --- Processing Outer Fold 5 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 5 F1: 0.9676
#   > ICAFS Final F1-Score: 0.9676 (Features: 40)
#     - CAFS Fold 5 F1: 0.9051
#   > CAFS Final F1-Score: 0.9051 (Features: 6)
#     - BBA Fold 5 F1: 1.0000
#   > BBA Final F1-Score: 1.0000 (Features: 194)
#     - PSO Fold 5 F1: 1.0000
#   > PSO Final F1-Score: 1.0000 (Features: 244)
#     - CS Fold 5 F1: 1.0000
#   > CS Final F1-Score: 1.0000 (Features: 205)
#
# >>> FINAL AVERAGED RESULTS FOR Olive <<<
#   ICAFS: F1 = 0.9246 (± 0.0615) | Features = 50.8 (± 11.5)
#   CAFS: F1 = 0.8824 (± 0.0270) | Features = 7.4 (± 2.9)
#   BBA: F1 = 0.9325 (± 0.0713) | Features = 189.8 (± 13.5)
#   PSO: F1 = 0.9385 (± 0.0754) | Features = 243.6 (± 7.1)
#   CS: F1 = 0.8641 (± 0.1005) | Features = 80.0 (± 93.3)
#
# ==================================================
# Starting NESTED CV for Dataset: Fruit Puree Dataset
# ==================================================
#
# --- Processing Outer Fold 1 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 1 F1: 0.9618
#   > ICAFS Final F1-Score: 0.9618 (Features: 10)
#     - CAFS Fold 1 F1: 0.9668
#   > CAFS Final F1-Score: 0.9668 (Features: 28)
#     - BBA Fold 1 F1: 0.9672
#   > BBA Final F1-Score: 0.9672 (Features: 67)
#     - PSO Fold 1 F1: 0.9672
#   > PSO Final F1-Score: 0.9672 (Features: 110)
#     - CS Fold 1 F1: 0.9672
#   > CS Final F1-Score: 0.9672 (Features: 105)
#
# --- Processing Outer Fold 2 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 2 F1: 0.9665
#   > ICAFS Final F1-Score: 0.9665 (Features: 32)
#     - CAFS Fold 2 F1: 0.9500
#   > CAFS Final F1-Score: 0.9500 (Features: 11)
#     - BBA Fold 2 F1: 0.9833
#   > BBA Final F1-Score: 0.9833 (Features: 62)
#     - PSO Fold 2 F1: 0.9833
#   > PSO Final F1-Score: 0.9833 (Features: 103)
#     - CS Fold 2 F1: 0.9396
#   > CS Final F1-Score: 0.9396 (Features: 5)
#
# --- Processing Outer Fold 3 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 3 F1: 0.9834
#   > ICAFS Final F1-Score: 0.9834 (Features: 11)
#     - CAFS Fold 3 F1: 0.9616
#   > CAFS Final F1-Score: 0.9616 (Features: 18)
#     - BBA Fold 3 F1: 0.9672
#   > BBA Final F1-Score: 0.9672 (Features: 66)
#     - PSO Fold 3 F1: 0.9616
#   > PSO Final F1-Score: 0.9616 (Features: 96)
#     - CS Fold 3 F1: 0.9616
#   > CS Final F1-Score: 0.9616 (Features: 74)
#
# --- Processing Outer Fold 4 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 4 F1: 0.9667
#   > ICAFS Final F1-Score: 0.9667 (Features: 13)
#     - CAFS Fold 4 F1: 0.9383
#   > CAFS Final F1-Score: 0.9383 (Features: 4)
#     - BBA Fold 4 F1: 0.9664
#   > BBA Final F1-Score: 0.9664 (Features: 71)
#     - PSO Fold 4 F1: 0.9607
#   > PSO Final F1-Score: 0.9607 (Features: 103)
#     - CS Fold 4 F1: 0.9834
#   > CS Final F1-Score: 0.9834 (Features: 99)
#
# --- Processing Outer Fold 5 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 5 F1: 0.9667
#   > ICAFS Final F1-Score: 0.9667 (Features: 27)
#     - CAFS Fold 5 F1: 0.9725
#   > CAFS Final F1-Score: 0.9725 (Features: 29)
#     - BBA Fold 5 F1: 0.9779
#   > BBA Final F1-Score: 0.9779 (Features: 65)
#     - PSO Fold 5 F1: 0.9779
#   > PSO Final F1-Score: 0.9779 (Features: 114)
#     - CS Fold 5 F1: 0.9779
#   > CS Final F1-Score: 0.9779 (Features: 70)
#
# >>> FINAL AVERAGED RESULTS FOR Fruit Puree Dataset <<<
#   ICAFS: F1 = 0.9690 (± 0.0074) | Features = 18.6 (± 9.1)
#   CAFS: F1 = 0.9578 (± 0.0123) | Features = 18.0 (± 9.7)
#   BBA: F1 = 0.9724 (± 0.0069) | Features = 66.2 (± 2.9)
#   PSO: F1 = 0.9701 (± 0.0090) | Features = 105.2 (± 6.2)
#   CS: F1 = 0.9659 (± 0.0152) | Features = 70.6 (± 35.5)
#
# ==================================================
# Starting NESTED CV for Dataset: CIS
# ==================================================
#
# --- Processing Outer Fold 1 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 1 F1: 0.9323
#   > ICAFS Final F1-Score: 0.9323 (Features: 2)
#     - CAFS Fold 1 F1: 0.9955
#   > CAFS Final F1-Score: 0.9955 (Features: 4)
#     - BBA Fold 1 F1: 0.9323
#   > BBA Final F1-Score: 0.9323 (Features: 2)
#     - PSO Fold 1 F1: 0.9585
#   > PSO Final F1-Score: 0.9585 (Features: 4)
#     - CS Fold 1 F1: 0.9323
#   > CS Final F1-Score: 0.9323 (Features: 2)
#
# --- Processing Outer Fold 2 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 2 F1: 0.9384
#   > ICAFS Final F1-Score: 0.9384 (Features: 2)
#     - CAFS Fold 2 F1: 0.9915
#   > CAFS Final F1-Score: 0.9915 (Features: 2)
#     - BBA Fold 2 F1: 0.9505
#   > BBA Final F1-Score: 0.9505 (Features: 2)
#     - PSO Fold 2 F1: 0.9515
#   > PSO Final F1-Score: 0.9515 (Features: 3)
#     - CS Fold 2 F1: 0.9505
#   > CS Final F1-Score: 0.9505 (Features: 2)
#
# --- Processing Outer Fold 3 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 3 F1: 0.9202
#   > ICAFS Final F1-Score: 0.9202 (Features: 2)
#     - CAFS Fold 3 F1: 0.9960
#   > CAFS Final F1-Score: 0.9960 (Features: 4)
#     - BBA Fold 3 F1: 0.9343
#   > BBA Final F1-Score: 0.9343 (Features: 2)
#     - PSO Fold 3 F1: 0.9910
#   > PSO Final F1-Score: 0.9910 (Features: 4)
#     - CS Fold 3 F1: 0.9343
#   > CS Final F1-Score: 0.9343 (Features: 2)
#
# --- Processing Outer Fold 4 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 4 F1: 0.9278
#   > ICAFS Final F1-Score: 0.9278 (Features: 2)
#     - CAFS Fold 4 F1: 0.9965
#   > CAFS Final F1-Score: 0.9965 (Features: 2)
#     - BBA Fold 4 F1: 0.9935
#   > BBA Final F1-Score: 0.9935 (Features: 3)
#     - PSO Fold 4 F1: 0.9570
#   > PSO Final F1-Score: 0.9570 (Features: 5)
#     - CS Fold 4 F1: 0.9155
#   > CS Final F1-Score: 0.9155 (Features: 2)
#
# --- Processing Outer Fold 5 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 5 F1: 0.9308
#   > ICAFS Final F1-Score: 0.9308 (Features: 2)
#     - CAFS Fold 5 F1: 0.9960
#   > CAFS Final F1-Score: 0.9960 (Features: 2)
#     - BBA Fold 5 F1: 0.9238
#   > BBA Final F1-Score: 0.9238 (Features: 2)
#     - PSO Fold 5 F1: 0.9645
#   > PSO Final F1-Score: 0.9645 (Features: 7)
#     - CS Fold 5 F1: 0.9308
#   > CS Final F1-Score: 0.9308 (Features: 2)
#
# >>> FINAL AVERAGED RESULTS FOR CIS <<<
#   ICAFS: F1 = 0.9299 (± 0.0060) | Features = 2.0 (± 0.0)
#   CAFS: F1 = 0.9951 (± 0.0018) | Features = 2.8 (± 1.0)
#   BBA: F1 = 0.9469 (± 0.0248) | Features = 2.2 (± 0.4)
#   PSO: F1 = 0.9645 (± 0.0139) | Features = 4.6 (± 1.4)
#   CS: F1 = 0.9327 (± 0.0111) | Features = 2.0 (± 0.0)
#
# ==================================================
# Starting NESTED CV for Dataset: Algarrobo
# ==================================================
#
# --- Processing Outer Fold 1 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 1 F1: 0.7400
#   > ICAFS Final F1-Score: 0.7400 (Features: 6)
#     - CAFS Fold 1 F1: 0.7600
#   > CAFS Final F1-Score: 0.7600 (Features: 8)
#     - BBA Fold 1 F1: 0.7649
#   > BBA Final F1-Score: 0.7649 (Features: 5)
#     - PSO Fold 1 F1: 0.7548
#   > PSO Final F1-Score: 0.7548 (Features: 7)
#     - CS Fold 1 F1: 0.8399
#   > CS Final F1-Score: 0.8399 (Features: 14)
#
# --- Processing Outer Fold 2 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 2 F1: 0.8450
#   > ICAFS Final F1-Score: 0.8450 (Features: 11)
#     - CAFS Fold 2 F1: 0.7400
#   > CAFS Final F1-Score: 0.7400 (Features: 7)
#     - BBA Fold 2 F1: 0.7596
#   > BBA Final F1-Score: 0.7596 (Features: 5)
#     - PSO Fold 2 F1: 0.7650
#   > PSO Final F1-Score: 0.7650 (Features: 15)
#     - CS Fold 2 F1: 0.7600
#   > CS Final F1-Score: 0.7600 (Features: 11)
#
# --- Processing Outer Fold 3 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 3 F1: 0.7649
#   > ICAFS Final F1-Score: 0.7649 (Features: 11)
#     - CAFS Fold 3 F1: 0.7244
#   > CAFS Final F1-Score: 0.7244 (Features: 6)
#     - BBA Fold 3 F1: 0.7347
#   > BBA Final F1-Score: 0.7347 (Features: 7)
#     - PSO Fold 3 F1: 0.7550
#   > PSO Final F1-Score: 0.7550 (Features: 11)
#     - CS Fold 3 F1: 0.7500
#   > CS Final F1-Score: 0.7500 (Features: 13)
#
# --- Processing Outer Fold 4 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 4 F1: 0.7899
#   > ICAFS Final F1-Score: 0.7899 (Features: 9)
#     - CAFS Fold 4 F1: 0.8300
#   > CAFS Final F1-Score: 0.8300 (Features: 7)
#     - BBA Fold 4 F1: 0.6916
#   > BBA Final F1-Score: 0.6916 (Features: 4)
#     - PSO Fold 4 F1: 0.8150
#   > PSO Final F1-Score: 0.8150 (Features: 12)
#     - CS Fold 4 F1: 0.7800
#   > CS Final F1-Score: 0.7800 (Features: 6)
#
# --- Processing Outer Fold 5 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 5 F1: 0.8150
#   > ICAFS Final F1-Score: 0.8150 (Features: 13)
#     - CAFS Fold 5 F1: 0.8150
#   > CAFS Final F1-Score: 0.8150 (Features: 10)
#     - BBA Fold 5 F1: 0.8000
#   > BBA Final F1-Score: 0.8000 (Features: 5)
#     - PSO Fold 5 F1: 0.8150
#   > PSO Final F1-Score: 0.8150 (Features: 13)
#     - CS Fold 5 F1: 0.7998
#   > CS Final F1-Score: 0.7998 (Features: 7)
#
# >>> FINAL AVERAGED RESULTS FOR Algarrobo <<<
#   ICAFS: F1 = 0.7910 (± 0.0368) | Features = 10.0 (± 2.4)
#   CAFS: F1 = 0.7739 (± 0.0415) | Features = 7.6 (± 1.4)
#   BBA: F1 = 0.7502 (± 0.0359) | Features = 5.2 (± 1.0)
#   PSO: F1 = 0.7810 (± 0.0280) | Features = 11.6 (± 2.7)
#   CS: F1 = 0.7859 (± 0.0320) | Features = 10.2 (± 3.2)
#
# ==================================================
# FINAL RESULTS TABLE (Phase 3 F1-Scores)
# ==================================================
#             Dataset    ICAFS     CAFS      BBA      PSO       CS
#              Cacao  0.996132 0.989981 0.999091 0.999091 0.999091
#                Meat 0.958406 0.974967 0.966337 0.974902 0.966972
#               Olive 0.924603 0.882379 0.932510 0.938475 0.864075
# Fruit Puree Dataset 0.969023 0.957816 0.972405 0.970143 0.965935
#                 CIS 0.929902 0.995100 0.946889 0.964497 0.932680
#           Algarrobo 0.790964 0.773882 0.750167 0.780965 0.785942
#
# ==================================================
# FINAL NUMBER OF FEATURES RESULTS TABLE
# ==================================================
#             Dataset ICAFS Features CAFS Features   BBA Features  PSO Features     CS Features
#              Cacao   23.2 (± 25.7)   5.0 (± 1.3) 435.8 (± 24.9) 596.0 (± 8.7) 487.0 (± 107.1)
#                Meat  15.2 (± 10.5)  10.0 (± 8.1) 141.4 (± 14.8) 197.8 (± 7.3)  106.6 (± 61.4)
#               Olive  50.8 (± 11.5)   7.4 (± 2.9) 189.8 (± 13.5) 243.6 (± 7.1)   80.0 (± 93.3)
# Fruit Puree Dataset   18.6 (± 9.1)  18.0 (± 9.7)   66.2 (± 2.9) 105.2 (± 6.2)   70.6 (± 35.5)
#                 CIS    2.0 (± 0.0)   2.8 (± 1.0)    2.2 (± 0.4)   4.6 (± 1.4)     2.0 (± 0.0)
#           Algarrobo   10.0 (± 2.4)   7.6 (± 1.4)    5.2 (± 1.0)  11.6 (± 2.7)    10.2 (± 3.2)
#
# ==================================================
# FINAL STANDARD DEVIATION RESULTS TABLE
# ==================================================
#             Dataset    ICAFS     CAFS      BBA      PSO       CS
#              Cacao  0.005740 0.014147 0.001818 0.001818 0.001818
#                Meat 0.037163 0.033350 0.031623 0.020492 0.030608
#               Olive 0.061451 0.027014 0.071335 0.075368 0.100514
# Fruit Puree Dataset 0.007443 0.012264 0.006928 0.009001 0.015236
#                 CIS 0.005957 0.001828 0.024850 0.013884 0.011129
#           Algarrobo 0.036798 0.041536 0.035948 0.028028 0.031969
#
# ==================================================
# STATISTICAL SIGNIFICANCE (Wilcoxon Signed-Rank Test)
# ==================================================
# ICAFS vs BBA:
#   - p-value: 0.4375
#   - Result: Difference is not statistically significant (p >= 0.05).
#
# ICAFS vs PSO:
#   - p-value: 0.1562
#   - Result: Difference is not statistically significant (p >= 0.05).
#
# ICAFS vs CS:
#   - p-value: 0.6875
#   - Result: Difference is not statistically significant (p >= 0.05).
#
# CAFS vs BBA:
#   - p-value: 1.0000
#   - Result: Difference is not statistically significant (p >= 0.05).
#
# CAFS vs PSO:
#   - p-value: 0.4375
#   - Result: Difference is not statistically significant (p >= 0.05).
#
# CAFS vs CS:
#   - p-value: 0.8438
#   - Result: Difference is not statistically significant (p >= 0.05).

# %% [markdown]
# # Quick test on small dataset

# %%
#datasets = [[df_x_cacao, y_cacao, "Cacao "],[meat_x, y_meat, "Meat"],[olive_x, y_olive, "Olive"],[fruits_pures_x, y_fruit_puree, "Fruit Puree Dataset"],[cis_x,y_cis, "CIS"],[algarrobo_x, y_algarrobo, "Algarrobo"]]
datasets = [[olive_x, y_olive, "Olive"]]

results = {'Dataset': [], 'ICAFS': [], 'CAFS': [], 'BBA': [], 'PSO': [], 'CS': []}
results_features = {'Dataset': [], 'ICAFS Features': [], 'CAFS Features': [], 'BBA Features': [], 'PSO Features': [], 'CS Features': []}

for X, y, name in datasets:
    scores,num_of_wavelengths,std_final = evaluate_dataset_nested(X, y, name)
    
    results['Dataset'].append(name)
    results['ICAFS'].append(scores['ICAFS'])
    results['CAFS'].append(scores['CAFS'])
    results['BBA'].append(scores['BBA'])
    results['PSO'].append(scores['PSO'])
    results['CS'].append(scores['CS'])

    results_features['Dataset'].append(name)
    results_features['ICAFS Features'].append(f"{num_of_wavelengths['ICAFS']:.1f} (± {std_final['ICAFS']:.1f})")
    results_features['CAFS Features'].append(f"{num_of_wavelengths['CAFS']:.1f} (± {std_final['CAFS']:.1f})")
    results_features['BBA Features'].append(f"{num_of_wavelengths['BBA']:.1f} (± {std_final['BBA']:.1f})")
    results_features['PSO Features'].append(f"{num_of_wavelengths['PSO']:.1f} (± {std_final['PSO']:.1f})")
    results_features['CS Features'].append(f"{num_of_wavelengths['CS']:.1f} (± {std_final['CS']:.1f})")

# Create a DataFrame for easy viewing and exporting to CSV
df_results = pd.DataFrame(results)
df_results_features = pd.DataFrame(results_features)

print("\n==================================================")
print("FINAL RESULTS TABLE (Phase 3 F1-Scores)")
print("==================================================")
print(df_results.to_string(index=False))

print("\n==================================================")
print("FINAL NUMBER OF FEATURES RESULTS TABLE")
print("==================================================")
print(df_results_features.to_string(index=False))


# Export to CSV so you don't lose the data!
df_results.to_csv('final_f1_scores_revision.csv', index=False)
df_results_features.to_csv('final_features_revision.csv', index=False)

# ---------------------------------------------------------
# PHASE 4: STATISTICAL VALIDATION (Reviewer 2 Fix)
# ---------------------------------------------------------
print("\n==================================================")
print("STATISTICAL SIGNIFICANCE (Wilcoxon Signed-Rank Test)")
print("==================================================")

baselines = ['BBA', 'PSO', 'CS']
for baseline in baselines:
    # Compare ICAFS scores against the baseline scores across the 6 datasets
    stat, p_value = wilcoxon(df_results['ICAFS'], df_results[baseline])
    
    print(f"ICAFS vs {baseline}:")
    print(f"  - p-value: {p_value:.4f}")
    if p_value < 0.05:
        print("  - Result: ICAFS is STATISTICALLY SIGNIFICANTLY better.\n")
    else:
        print("  - Result: Difference is not statistically significant (p >= 0.05).\n")
for baseline in baselines:
    # Compare CAFS scores against the baseline scores across the 6 datasets
    stat, p_value = wilcoxon(df_results['CAFS'], df_results[baseline])
    
    print(f"CAFS vs {baseline}:")
    print(f"  - p-value: {p_value:.4f}")
    if p_value < 0.05:
        print("  - Result: CAFS is STATISTICALLY SIGNIFICANTLY better.\n")
    else:
        print("  - Result: Difference is not statistically significant (p >= 0.05).\n")
# Out:
# ==================================================
# Starting NESTED CV for Dataset: Olive
# ==================================================
#
# --- Processing Outer Fold 1 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 1 F1: 0.8438
#   > ICAFS Final F1-Score: 0.8438 (Features: 34)
#     - CAFS Fold 1 F1: 0.8438
#   > CAFS Final F1-Score: 0.8438 (Features: 5)
#     - BBA Fold 1 F1: 0.8438
#   > BBA Final F1-Score: 0.8438 (Features: 170)
#     - PSO Fold 1 F1: 0.8438
#   > PSO Final F1-Score: 0.8438 (Features: 246)
#     - CS Fold 1 F1: 0.8438
#   > CS Final F1-Score: 0.8438 (Features: 183)
#
# --- Processing Outer Fold 2 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 2 F1: 1.0000
#   > ICAFS Final F1-Score: 1.0000 (Features: 58)
#     - CAFS Fold 2 F1: 0.8987
#   > CAFS Final F1-Score: 0.8987 (Features: 6)
#     - BBA Fold 2 F1: 0.9702
#   > BBA Final F1-Score: 0.9702 (Features: 180)
#     - PSO Fold 2 F1: 1.0000
#   > PSO Final F1-Score: 1.0000 (Features: 242)
#     - CS Fold 2 F1: 0.9702
#   > CS Final F1-Score: 0.9702 (Features: 190)
#
# --- Processing Outer Fold 3 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 3 F1: 0.8605
#   > ICAFS Final F1-Score: 0.8605 (Features: 63)
#     - CAFS Fold 3 F1: 0.8560
#   > CAFS Final F1-Score: 0.8560 (Features: 7)
#     - BBA Fold 3 F1: 0.8486
#   > BBA Final F1-Score: 0.8486 (Features: 196)
#     - PSO Fold 3 F1: 0.8486
#   > PSO Final F1-Score: 0.8486 (Features: 254)
#     - CS Fold 3 F1: 0.9080
#   > CS Final F1-Score: 0.9080 (Features: 202)
#
# --- Processing Outer Fold 4 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 4 F1: 0.9511
#   > ICAFS Final F1-Score: 0.9511 (Features: 59)
#     - CAFS Fold 4 F1: 0.9083
#   > CAFS Final F1-Score: 0.9083 (Features: 13)
#     - BBA Fold 4 F1: 1.0000
#   > BBA Final F1-Score: 1.0000 (Features: 209)
#     - PSO Fold 4 F1: 1.0000
#   > PSO Final F1-Score: 1.0000 (Features: 232)
#     - CS Fold 4 F1: 1.0000
#   > CS Final F1-Score: 1.0000 (Features: 221)
#
# --- Processing Outer Fold 5 / 5 ---
#   > Running Feature Selection on Training Data...
#   > Tuning SVMs and Evaluating on Vault Data...
#     - ICAFS Fold 5 F1: 0.9676
#   > ICAFS Final F1-Score: 0.9676 (Features: 40)
#     - CAFS Fold 5 F1: 0.9051
#   > CAFS Final F1-Score: 0.9051 (Features: 6)
#     - BBA Fold 5 F1: 1.0000
#   > BBA Final F1-Score: 1.0000 (Features: 194)
#     - PSO Fold 5 F1: 1.0000
#   > PSO Final F1-Score: 1.0000 (Features: 244)
#     - CS Fold 5 F1: 1.0000
#   > CS Final F1-Score: 1.0000 (Features: 205)
#
# >>> FINAL AVERAGED RESULTS FOR Olive <<<
#   ICAFS: F1 = 0.9246 | Features = 50.8 (± 11.5)
#   CAFS: F1 = 0.8824 | Features = 7.4 (± 2.9)
#   BBA: F1 = 0.9325 | Features = 189.8 (± 13.5)
#   PSO: F1 = 0.9385 | Features = 243.6 (± 7.1)
#   CS: F1 = 0.9444 | Features = 200.2 (± 13.1)
#
# ==================================================
# FINAL RESULTS TABLE (Phase 3 F1-Scores)
# ==================================================
# Dataset    ICAFS     CAFS     BBA      PSO       CS
#   Olive 0.924603 0.882379 0.93251 0.938475 0.944393
#
# ==================================================
# FINAL NUMBER OF FEATURES RESULTS TABLE
# ==================================================
# Dataset ICAFS Features CAFS Features   BBA Features  PSO Features    CS Features
#   Olive  50.8 (± 11.5)   7.4 (± 2.9) 189.8 (± 13.5) 243.6 (± 7.1) 200.2 (± 13.1)
#
# ==================================================
# STATISTICAL SIGNIFICANCE (Wilcoxon Signed-Rank Test)
# ==================================================
# ICAFS vs BBA:
#   - p-value: 1.0000
#   - Result: Difference is not statistically significant (p >= 0.05).
#
# ICAFS vs PSO:
#   - p-value: 1.0000
#   - Result: Difference is not statistically significant (p >= 0.05).
#
# ICAFS vs CS:
#   - p-value: 1.0000
#   - Result: Difference is not statistically significant (p >= 0.05).
#
# CAFS vs BBA:
#   - p-value: 1.0000
#   - Result: Difference is not statistically significant (p >= 0.05).
#
# CAFS vs PSO:
#   - p-value: 1.0000
#   - Result: Difference is not statistically significant (p >= 0.05).
#
# CAFS vs CS:
#   - p-value: 1.0000
#   - Result: Difference is not statistically significant (p >= 0.05).
